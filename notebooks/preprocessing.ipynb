# %% [markdown]
# # Preprocessing Notebook

# %% [markdown]
# ## Load Dataset
#
# Data available for download at https://www.gbif.org/occurrence/download/0004691-251025141854904
#
# Covers 2015-2020 in South America. Over 30 million records.

# %%
import pandas as pd

eod_data = pd.read_csv('../data/0004691-251025141854904.csv', delimiter='\t')
eod_data.head(n=2)
# Out:
#        gbifID                            datasetKey  \
# 0  3177189382  4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# 1  2045649326  4fa7b334-ce0d-4e88-aaae-2e0c138d049e
#
#                          occurrenceID   kingdom    phylum class  \
# 0  URN:catalog:CLO:EBIRD:OBS966912869  Animalia  Chordata  Aves
# 1  URN:catalog:CLO:EBIRD:OBS487895750  Animalia  Chordata  Aves
#
#              order       family         genus                   species  ...  \
# 0    Passeriformes    Parulidae  Basileuterus  Basileuterus culicivorus  ...
# 1  Accipitriformes  Cathartidae      Coragyps          Coragyps atratus  ...
#
#    identifiedBy dateIdentified    license rightsHolder  recordedBy typeStatus  \
# 0           NaN            NaN  CC_BY_4_0          NaN  obsr918297        NaN
# 1           NaN            NaN  CC_BY_4_0          NaN  obsr204697        NaN
#
#   establishmentMeans           lastInterpreted mediaType  \
# 0                NaN  2025-10-08T14:29:54.530Z       NaN
# 1                NaN  2025-10-08T14:29:54.530Z       NaN
#
#                                                issue
# 0  CONTINENT_DERIVED_FROM_COORDINATES;TAXON_CONCE...
# 1  CONTINENT_DERIVED_FROM_COORDINATES;TAXON_CONCE...
#
# [2 rows x 50 columns]

# %% [markdown]
# ## Remove unnecessary columns

# %%
print(eod_data.columns.tolist())
print(len(eod_data.columns))
# Out:
# ['gbifID', 'datasetKey', 'occurrenceID', 'kingdom', 'phylum', 'class', 'order', 'family', 'genus', 'species', 'infraspecificEpithet', 'taxonRank', 'scientificName', 'verbatimScientificName', 'verbatimScientificNameAuthorship', 'countryCode', 'locality', 'stateProvince', 'occurrenceStatus', 'individualCount', 'publishingOrgKey', 'decimalLatitude', 'decimalLongitude', 'coordinateUncertaintyInMeters', 'coordinatePrecision', 'elevation', 'elevationAccuracy', 'depth', 'depthAccuracy', 'eventDate', 'day', 'month', 'year', 'taxonKey', 'speciesKey', 'basisOfRecord', 'institutionCode', 'collectionCode', 'catalogNumber', 'recordNumber', 'identifiedBy', 'dateIdentified', 'license', 'rightsHolder', 'recordedBy', 'typeStatus', 'establishmentMeans', 'lastInterpreted', 'mediaType', 'issue']
# 50

# %%
keep_cols = {
    'genus','species',
    'countryCode','locality','stateProvince',
    'individualCount',
    'decimalLatitude','decimalLongitude',
    'eventDate','recordedBy',
    }

refined_eod_data = eod_data.drop(columns=[col for col in eod_data.columns if col not in keep_cols])
refined_eod_data['eventDate'] = pd.to_datetime(refined_eod_data['eventDate'], errors='coerce')
refined_eod_data.head(n=2)
# Out:
#           genus                   species countryCode  \
# 0  Basileuterus  Basileuterus culicivorus          CO
# 1      Coragyps          Coragyps atratus          TT
#
#                                             locality            stateProvince  \
# 0  Finca La Esmeralda - El Cairo - Valle del Cauc...          Valle del Cauca
# 1                                       Arena Forest  Couva-Tabaquite-Talparo
#
#    individualCount  decimalLatitude  decimalLongitude  eventDate  recordedBy
# 0              1.0         4.733494        -76.209640 2020-07-04  obsr918297
# 1              NaN        10.569455        -61.248222 2017-03-29  obsr204697

# %% [markdown]
# Note: EOD does not provide unique checklist identifiers. We will approximate this by grouping on eventDate, countryCode, locality, and stateProvince. Together these will roughly designate a unique sampling event for our use case...

# %%
checklist_cols = ['eventDate', 'countryCode', 'locality', 'stateProvince']
refined_eod_data['checklist_id'] = refined_eod_data.groupby(checklist_cols).ngroup(ascending=True)
refined_eod_data.head(n=2)
print(f'Number of checklists: {refined_eod_data["checklist_id"].nunique()}')
# Out:
# Number of checklists: 1032227

# %% [markdown]
# ## Convert to parquet file format
#
# CSV is inefficient for storing/loading such a large dataset. We'll convert to parquet format to increase efficiency when loading/storing data.

# %%
refined_eod_data.to_parquet('/home/noahg/MATH316/project2/data/0004691-251025141854904.parquet')

# %%
# test loading parquet file - should be much faster than loading CSV
test_data = pd.read_parquet('/home/noahg/MATH316/project2/data/0004691-251025141854904.parquet')
test_data.head(n=5)
# Out:
#           genus                   species countryCode  \
# 0  Basileuterus  Basileuterus culicivorus          CO
# 1      Coragyps          Coragyps atratus          TT
# 2       Egretta          Egretta caerulea          TT
# 3     Setophaga       Setophaga pitiayumi          AR
# 4      Zebrilus        Zebrilus undulatus          BR
#
#                                             locality            stateProvince  \
# 0  Finca La Esmeralda - El Cairo - Valle del Cauc...          Valle del Cauca
# 1                                       Arena Forest  Couva-Tabaquite-Talparo
# 2                                      Rahamut Trace                  Siparia
# 3                                    Cañada de Grass                 Santa Fe
# 4                    Alta Floresta--rio Santa Helena              Mato Grosso
#
#    individualCount  decimalLatitude  decimalLongitude  eventDate   recordedBy  \
# 0              1.0         4.733494        -76.209640 2020-07-04   obsr918297
# 1              NaN        10.569455        -61.248222 2017-03-29   obsr204697
# 2              2.0        10.200900        -61.481125 2020-09-06  obsr1080831
# 3              1.0       -29.918184        -60.310024 2020-05-01   obsr914504
# 4              2.0        -9.926295        -56.308765 2016-02-20   obsr412230
#
#    checklist_id
# 0      893563.0
# 1      202736.0
# 2      936373.0
# 3      843373.0
# 4       86491.0
